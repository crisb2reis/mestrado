# %% [markdown]
# Importação das Bibliotecas

# %%
import os
import zipfile
import shutil
import cv2
import numpy as np
import pandas as pd
from PIL import Image
import concurrent.futures
import matplotlib.pyplot as plt

import rasterio as rs
from skimage.transform import resize

# %% [markdown]
# Inicialização das Variáveis que seram utilizadas dirante a execução do código

# %%
IMG_HEIGHT = 64  # Definir a altura das imagens
IMG_WIDTH = 64   # Definir a largura das imagens
IMG_MASK_CHANNELS = 1  # Número de canais de imagem mascara
IMG_CHANNELS = 2  # Número de canais de imagem (bandas 11 e 12)
IMG_COLOR_CHANNELS = 3  # Número de canais de imagem coloridas
NUMERO_IMAGEN = 1
tamanho_recorte = IMG_HEIGHT

# %% [markdown]
# Diretório das Imagens e Saídas de .CSV e DataFrame

# %%
# Local onde as imagens seram salvas em seu computador
# path = "/home/cristiano/Imagens/"
path = "/home/emanoelcepr/Imagens/"

# # Treino Sentinel-2
origem =  path + "imagens_originais/Sentinel-2/treino/"
diretorio_imagens =  path + "imagens_originais/Sentinel-2/treino_processadas/"

# # Teste Sentinel-2
# origem = path + "imagens_originais/Sentinel-2/teste/"
# diretorio_imagens =  path + "imagens_originais/Sentinel-2/teste_processadas/"

# # Teste Landsat-8
# origem =  path + "imagens_originais/Landsat-8/teste/"
# diretorio_imagens =  path + "/imagens_originais/Landsat-8/teste_processadas/"

# %% [markdown]
# Extrair as imagens para o diretório onde seram processadas e adicionando um número para diferenciar as imagens de mesmo nome.

# %%
# Verifica se o diretório de destino existe, caso contrário, cria-o
if not os.path.exists(diretorio_imagens):
    os.makedirs(diretorio_imagens)

# Percorre todas as pastas compactadas no diretório de origem
for pasta_compactada in os.listdir(origem):
    caminho_pasta_compactada = os.path.join(origem, pasta_compactada)

    # Verifica se o item é uma pasta compactada
    if zipfile.is_zipfile(caminho_pasta_compactada):
        # Extrai o conteúdo do arquivo compactado para uma pasta temporária
        pasta_temporaria = os.path.join(diretorio_imagens, "temp")
        with zipfile.ZipFile(caminho_pasta_compactada, 'r') as zip_ref:
            zip_ref.extractall(pasta_temporaria)

        # Percorre todas as imagens na pasta temporária
        for nome_imagem in os.listdir(pasta_temporaria):
            caminho_imagem = os.path.join(pasta_temporaria, nome_imagem)

            # Verifica se o item é um arquivo de imagem
            if os.path.isfile(caminho_imagem):
                # Define o novo nome da imagem com o número no início
                novo_nome_imagem = f"{NUMERO_IMAGEN}_{nome_imagem}"

                # Move a imagem para o diretório de destino com o novo nome
                caminho_destino_imagem = os.path.join(diretorio_imagens, novo_nome_imagem)
                shutil.move(caminho_imagem, caminho_destino_imagem)

                # Incrementa o número para a próxima imagem
                NUMERO_IMAGEN += 1

        # Remove a pasta temporária após processar todas as imagens
        shutil.rmtree(pasta_temporaria)

print("Descompactação concluída.")
# Out:
# Descompactação concluída.

# %% [markdown]
# Neste ponte é realizado a criação das máscaras, tendo como base a Imagem de Banda12 e como Limiar o valor de 180. As máscaras criadas seram identificadas com o nome Mask e seus pixel seram normalizados para que o o Pixel de fundo tenha o valor 0 e a imagem o valor 1.

# %%
from PIL import Image
import os
import concurrent.futures

def modificar_nome_arquivo(nome_arquivo):
    # Remover a sequência "_(Raw)"
    nome_arquivo_modificado = nome_arquivo.replace("B12(Raw)", " ")
    return nome_arquivo_modificado

def aplicar_limiar(imagem, limiar):
    # Converte a imagem para escala de cinza
    imagem_cinza = imagem.convert('L')

    # Binariza a imagem usando o limiar
    imagem_binarizada = imagem_cinza.point(lambda p: p > limiar and 255)

    return imagem_binarizada

def limiar_imagem(caminho_arquivo, output_dir):
    # Carrega a imagem
    imagem = Image.open(caminho_arquivo)

    # Aplicar o limiar de 180
    imagem_binarizada = aplicar_limiar(imagem, 180)

    # Obter o nome do arquivo sem a extensão
    nome_arquivo = os.path.basename(caminho_arquivo)
    nome_sem_extensao = os.path.splitext(nome_arquivo)[0]

    # Salvar a imagem binarizada com "_Mask" antes da extensão no diretório de saída
    nome_mask = nome_sem_extensao + "Mask.tiff"
    caminho_mask = os.path.join(output_dir, nome_mask)
    imagem_binarizada.save(caminho_mask)

def limiar_imagens(diretorio, output_dir):
    with concurrent.futures.ThreadPoolExecutor(max_workers=11) as executor:
        for nome_arquivo in os.listdir(diretorio):
            if nome_arquivo.endswith("B12_(Raw).tiff"):
                # Limpar o nome do arquivo
                nome_arquivo_limpo = modificar_nome_arquivo(nome_arquivo)

                # Obter o caminho completo do arquivo
                caminho_arquivo = os.path.join(diretorio, nome_arquivo)

                # Processar a imagem em um thread separado
                executor.submit(limiar_imagem, caminho_arquivo, output_dir)

# Utiliza processamento paralelo com max threads
with concurrent.futures.ThreadPoolExecutor(max_workers=11) as executor:
    futures = [executor.submit(limiar_imagens, diretorio_imagens, diretorio_imagens)]

# %% [markdown]
# Recorte das imagens em 64x64
# As imagens que possuem coordenadas geográficas precisam ser recortadas de tal forma que não percam esses dados. Já as máscaras não tem essa necessidade, pois não possiem essa caracteristica.

# %%
import rasterio

def recortar_imagens(diretorio, tamanho_recorte):
    global numero_imagem
    
    # Percorre todas as imagens no diretório
    for nome_arquivo in os.listdir(diretorio):
        caminho_arquivo = os.path.join(diretorio, nome_arquivo)
        
        # Verifica se a imagem contém "B12_(Raw)", "B11_(Raw)" ou "Wildfires" no nome
        if "B12_(Raw)" in nome_arquivo or "B11_(Raw)" in nome_arquivo or "Wildfires" in nome_arquivo:
            # Carrega a imagem usando o rasterio para obter os metadados
            with rasterio.open(caminho_arquivo) as img:
                # Obtém as dimensões da imagem
                altura, largura = img.height, img.width
                
                # Obtém os metadados da imagem
                metadados = img.meta
            
            # Calcula o número de recortes horizontais e verticais
            num_recortes_horizontais = largura // tamanho_recorte
            num_recortes_verticais = altura // tamanho_recorte
            
            # Realiza o recorte e salva as imagens resultantes
            for i in range(num_recortes_horizontais):
                for j in range(num_recortes_verticais):
                    # Define as coordenadas do retângulo de recorte
                    esquerda = i * tamanho_recorte
                    superior = j * tamanho_recorte
                    direita = (i + 1) * tamanho_recorte
                    inferior = (j + 1) * tamanho_recorte
                    
                    # Carrega a imagem novamente para o recorte
                    with rasterio.open(caminho_arquivo) as img:
                        # Realiza o recorte usando a função read
                        recorte = img.read(window=((superior, inferior), (esquerda, direita)))
                        transform = rasterio.windows.transform(window=((superior, inferior), (esquerda, direita)), transform=img.transform)
                    
                    # Separa o nome do arquivo e a extensão
                    nome, extensao = os.path.splitext(nome_arquivo)
                    numero = nome_arquivo.split("_")[0]
                    nome = nome[nome.index('_'):]
                    
                    # Constrói o novo nome de arquivo com o prefixo desejado
                    novo_nome_arquivo = f"{str(numero).zfill(6)}{nome}_recorte_{i}_{j}{extensao}"
                    
                    # Salva o recorte em um novo arquivo com os mesmos metadados da imagem original
                    caminho_recorte = os.path.join(diretorio, novo_nome_arquivo)
                    with rasterio.open(caminho_recorte, 'w', **metadados) as dest:
                        dest.write(recorte)
                    
                    # Incrementa o número para a próxima imagem
                    numero_imagem += 1
                    
            # Remove a imagem original
            os.remove(caminho_arquivo)
        
        # Verifica se a imagem contém "Mask" no nome
        elif "Mask" in nome_arquivo:
            # Carrega a imagem
            imagem = cv2.imread(caminho_arquivo)
            
            # Obtém as dimensões da imagem
            altura, largura, _ = imagem.shape
            
            # Calcula o número de recortes horizontais e verticais
            num_recortes_horizontais = largura // tamanho_recorte
            num_recortes_verticais = altura // tamanho_recorte
            
            # Realiza o recorte e salva as imagens resultantes
            for i in range(num_recortes_horizontais):
                for j in range(num_recortes_verticais):
                    # Define as coordenadas do retângulo de recorte
                    esquerda = i * tamanho_recorte
                    superior = j * tamanho_recorte
                    direita = (i + 1) * tamanho_recorte
                    inferior = (j + 1) * tamanho_recorte
                    
                    # Realiza o recorte
                    recorte = imagem[superior:inferior, esquerda:direita]
                    
                    # Separa o nome do arquivo e a extensão
                    nome, extensao = os.path.splitext(nome_arquivo)
                    numero = nome_arquivo.split("_")[0]
                    nome = nome[nome.index('_'):]
                    
                    # Constrói o novo nome de arquivo com o prefixo desejado
                    novo_nome_arquivo = f"{str(numero).zfill(6)}{nome}_recorte_{i}_{j}{extensao}"
                    
                    # Salva o recorte em um novo arquivo
                    caminho_recorte = os.path.join(diretorio, novo_nome_arquivo)
                    cv2.imwrite(caminho_recorte, recorte)
                    
                    # Incrementa o número para a próxima imagem
                    numero_imagem += 1
                    
            # Remove a imagem original
            os.remove(caminho_arquivo)
            
    # Libera a memória das imagens
    cv2.destroyAllWindows()

numero_imagem = 0
recortar_imagens(diretorio_imagens, tamanho_recorte)
# Out:
# /home/emanoelcepr/.local/lib/python3.10/site-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# /home/emanoelcepr/.local/lib/python3.10/site-packages/rasterio/__init__.py:314: NotGeoreferencedWarning: The given matrix is equal to Affine.identity or its flipped counterpart. GDAL may ignore this matrix and save no geotransform without raising an error. This behavior is somewhat driver-specific.
#   dataset = writer(

# %% [markdown]
# redimenciona as imagens em 64x64

# %%
import os
import cv2
import rasterio

def redimensionar_imagem(imagem, altura_desejada, largura_desejada):
    return cv2.resize(imagem, (largura_desejada, altura_desejada), interpolation=cv2.INTER_LINEAR)

def pad_imagem(imagem, altura_desejada, largura_desejada):
    altura_atual, largura_atual, _ = imagem.shape

    diferenca_altura = altura_desejada - altura_atual
    diferenca_largura = largura_desejada - largura_atual

    # Calcular quantos pixels devem ser adicionados em cada lado da imagem
    topo = diferenca_altura // 2
    base = diferenca_altura - topo
    esquerda = diferenca_largura // 2
    direita = diferenca_largura - esquerda

    # Preencher a imagem com bordas para atingir o tamanho desejado
    imagem_pad = cv2.copyMakeBorder(imagem, topo, base, esquerda, direita, cv2.BORDER_CONSTANT, value=(0, 0, 0))

    return imagem_pad

def redimensionar_imagens_no_diretorio(diretorio_imagens, altura_desejada, largura_desejada):
    for nome_arquivo in os.listdir(diretorio_imagens):
        caminho_arquivo = os.path.join(diretorio_imagens, nome_arquivo)

        # Verifica se o arquivo é uma imagem válida
        if not os.path.isfile(caminho_arquivo) or not nome_arquivo.lower().endswith(('.tiff')):
            continue

        # Verifica se o nome do arquivo contém os substrings desejados
        if "B12_(Raw)" in nome_arquivo or "B11_(Raw)" in nome_arquivo or "B12_(Raw)Mask" in nome_arquivo:
            # Abre a imagem usando rasterio para obter os metadados de georreferenciamento
            with rasterio.open(caminho_arquivo) as src:
                profile = src.profile
                imagem = src.read(1)  # Lê a primeira banda da imagem

            # Redimensiona a imagem e mantém os metadados de georreferenciamento
            imagem_redimensionada = redimensionar_imagem(imagem, altura_desejada, largura_desejada)

            # Atualiza os metadados de georreferenciamento no arquivo TIFF
            profile.update(height=altura_desejada, width=largura_desejada, count=1)

            # Salva a imagem redimensionada com os metadados de georreferenciamento em um arquivo temporário
            novo_caminho_arquivo_temporario = os.path.join(diretorio_imagens, f"redimensionada_temp_{nome_arquivo}")
            with rasterio.open(novo_caminho_arquivo_temporario, 'w', **profile) as dst:
                dst.write(imagem_redimensionada, 1)  # Grava a imagem redimensionada na primeira banda

            # Exclui o arquivo original
            os.remove(caminho_arquivo)

            # Renomeia o arquivo temporário com o nome original da imagem
            novo_caminho_arquivo = os.path.join(diretorio_imagens, nome_arquivo)
            os.rename(novo_caminho_arquivo_temporario, novo_caminho_arquivo)
        elif "Wildfires" in nome_arquivo:
            # Carrega a imagem
            imagem = cv2.imread(caminho_arquivo)

            # Verifica se a imagem foi carregada corretamente
            if imagem is None:
                print(f"Erro ao carregar a imagem: {caminho_arquivo}")
                continue

            # Redimensiona a imagem para o tamanho desejado
            imagem_redimensionada = redimensionar_imagem(imagem, altura_desejada, largura_desejada)

            # Preenche a imagem com bordas se necessário para atingir o tamanho desejado
            imagem_pad = pad_imagem(imagem_redimensionada, altura_desejada, largura_desejada)

            # Salva a imagem redimensionada no mesmo caminho de origem
            cv2.imwrite(caminho_arquivo, imagem_pad)


# Defina a altura e largura desejadas para as imagens
altura_desejada = 64
largura_desejada = 64

# Redimensione apenas as imagens que contêm os substrings desejados e substitua o arquivo original pelo redimensionado
redimensionar_imagens_no_diretorio(diretorio_imagens, altura_desejada, largura_desejada)

# %% [markdown]
# É criado um dataframe para salvar ID_Imagem, Banda12, Linha, Coluna, Latitude e Longitude de cada imagem com o limiar maior ou igual a 180. Isso é feito para que seja possivel obter as coordenadas geográficas durante a visualização das imagens.

# %%
def encontrar_coordenadas_todos_pixels_true(diretorio_imagens, limite_valor_pixel):
    # Lista para armazenar as informações de ID da imagem, nome do arquivo, linha, coluna, latitude e longitude de cada pixel true
    informacoes_pixels_true = []

    # Iterar sobre os arquivos no diretório
    for arquivo in os.listdir(diretorio_imagens):
        
        if ("B12_(Raw)" in arquivo or "B07_(Raw)" in arquivo) and arquivo.endswith(".tiff"):
            caminho_arquivo = os.path.join(diretorio_imagens, arquivo)

            # Extrair o nome do arquivo e sua extensão usando os.path.basename
            nome_arquivo = os.path.basename(caminho_arquivo)

            # Extrair o ID da imagem do nome do arquivo (assumindo que o ID está antes do primeiro "_")
            id_imagem = nome_arquivo.split("_")[0]

            # Abrir a imagem usando o rasterio
            with rs.open(caminho_arquivo) as img:
                # Ler a matriz de pixels da imagem
                matriz_pixels = img.read(1)

                # Encontrar as posições de todos os pixels true
                indices_pixels_true = np.where(matriz_pixels >= limite_valor_pixel)
                if len(indices_pixels_true[0]) > 0:
                    linhas, colunas = indices_pixels_true

                    # Obter as coordenadas de todos os pixels usando o transformador da imagem
                    transformador = img.transform
                    latitudes, longitudes = rs.transform.xy(transformador, linhas, colunas)

                    # Adicionar as informações de cada pixel true à lista
                    for linha, coluna, latitude, longitude in zip(linhas, colunas, latitudes, longitudes):
                        informacoes_pixels_true.append((id_imagem, nome_arquivo, linha, coluna, latitude, longitude))

    return informacoes_pixels_true

# Valor limite do pixel para considerá-lo como "true"
limite_valor_pixel = 180

# Encontrar as coordenadas de todos os pixels true nas imagens do diretório
lista_informacoes = encontrar_coordenadas_todos_pixels_true(diretorio_imagens, limite_valor_pixel)

# Criar um DataFrame a partir da lista de informações
df_metadados = pd.DataFrame(lista_informacoes, columns=["ID_Imagem", "Banda12", "Linha", "Coluna", "Latitude", "Longitude"])

# Ordenar o DataFrame pela coluna "ID_Imagem"
df_metadados.sort_values(by="ID_Imagem", inplace=True)

# Salvar o DataFrame em um arquivo CSV (ou outro formato de sua escolha)
destino_csv = os.path.join(diretorio_imagens, "metadados.csv")
df_metadados.to_csv(destino_csv, index= False )

# %%
import os

def renomear_imagens(diretorio):
    for nome_arquivo in os.listdir(diretorio):
        caminho_arquivo_antigo = os.path.join(diretorio, nome_arquivo)

        # Verifica se o arquivo é uma imagem válida
        if not os.path.isfile(caminho_arquivo_antigo) or not nome_arquivo.lower().endswith(('.tiff')):
            continue

        # Verifica se o nome do arquivo contém "B12_(Raw)Mask"
        if "B12_(Raw)Mask" in nome_arquivo:
            # Constrói o novo nome de arquivo com a palavra "Mask"
            novo_nome_arquivo = nome_arquivo.replace("B12_(Raw)Mask", "Mask")

            # Renomeia o arquivo
            caminho_arquivo_novo = os.path.join(diretorio, novo_nome_arquivo)
            os.rename(caminho_arquivo_antigo, caminho_arquivo_novo)
            print(f"Imagem renomeada: {nome_arquivo} -> {novo_nome_arquivo}")

# Renomeia as imagens que contêm "B12_(Raw)Mask" no nome para "Mask"
renomear_imagens(diretorio_imagens)
# Out:
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_3.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_5_3.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_1.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_2_1.tiff
# Imagem renomeada: 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_3.tiff -> 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_Mask_recorte_5_3.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_6.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_1_6.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_8_1.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_8_1.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_8.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_4_8.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_3.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_5_3.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_4.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_5_4.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_6.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_2_6.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_17_0.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_17_0.tiff
# Imagem renomeada: 000083_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_0.tiff -> 000083_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_4_0.tiff
# Imagem renomeada: 000085_2023-02-07-00:00_2023-02-07-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000085_2023-02-07-00:00_2023-02-07-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000069_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000069_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000075_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_0.tiff -> 000075_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_Mask_recorte_1_0.tiff
# Imagem renomeada: 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_2.tiff -> 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_Mask_recorte_2_2.tiff
# Imagem renomeada: 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_2.tiff -> 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_0_2.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_28_6.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_28_6.tiff
# Imagem renomeada: 000102_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_1.tiff -> 000102_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_Mask_recorte_1_1.tiff
# Imagem renomeada: 000079_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_4.tiff -> 000079_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_Mask_recorte_2_4.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_5.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_4_5.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_0.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_1_0.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_8.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_0_8.tiff
# Imagem renomeada: 000129_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000129_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_12_12.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_12_12.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_8.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_6_8.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_27_7.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_27_7.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_17_4.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_17_4.tiff
# Imagem renomeada: 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_5.tiff -> 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_Mask_recorte_1_5.tiff
# Imagem renomeada: 000170_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_2.tiff -> 000170_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_1_2.tiff
# Imagem renomeada: 000141_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_3.tiff -> 000141_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_Mask_recorte_2_3.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_18_0.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_18_0.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_28_2.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_28_2.tiff
# Imagem renomeada: 000050_2022-08-24-00:00_2022-08-24-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_0.tiff -> 000050_2022-08-24-00:00_2022-08-24-23:59_Sentinel-2_L2A_Mask_recorte_6_0.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_30_1.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_30_1.tiff
# Imagem renomeada: 000129_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_1.tiff -> 000129_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_1_1.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_21_11.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_21_11.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_16_1.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_16_1.tiff
# Imagem renomeada: 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_3.tiff -> 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_Mask_recorte_7_3.tiff
# Imagem renomeada: 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_0.tiff -> 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_3_0.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_15_13.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_15_13.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_17_5.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_17_5.tiff
# Imagem renomeada: 000170_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000170_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_0.tiff -> 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_Mask_recorte_3_0.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_10_4.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_10_4.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_15_0.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_15_0.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_7.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_5_7.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_21_3.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_21_3.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_0.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_7_0.tiff
# Imagem renomeada: 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_2.tiff -> 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_Mask_recorte_3_2.tiff
# Imagem renomeada: 000005_2022-08-23-00:00_2022-08-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_3.tiff -> 000005_2022-08-23-00:00_2022-08-23-23:59_Sentinel-2_L2A_Mask_recorte_2_3.tiff
# Imagem renomeada: 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_0.tiff -> 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_Mask_recorte_1_0.tiff
# Imagem renomeada: 000167_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000167_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_1.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_1_1.tiff
# Imagem renomeada: 000094_2021-01-05-00:00_2021-01-05-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_2.tiff -> 000094_2021-01-05-00:00_2021-01-05-23:59_Sentinel-2_L2A_Mask_recorte_7_2.tiff
# Imagem renomeada: 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_2.tiff -> 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_3_2.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_27_6.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_27_6.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_4.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_2_4.tiff
# Imagem renomeada: 000029_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000029_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_0.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_3_0.tiff
# Imagem renomeada: 000029_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000029_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000170_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_4.tiff -> 000170_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_0_4.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_9_1.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_9_1.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_15_12.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_15_12.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_10_2.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_10_2.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_1.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_3_1.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_13_9.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_13_9.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_7.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_5_7.tiff
# Imagem renomeada: 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_0.tiff -> 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_1_0.tiff
# Imagem renomeada: 000005_2022-08-23-00:00_2022-08-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_1.tiff -> 000005_2022-08-23-00:00_2022-08-23-23:59_Sentinel-2_L2A_Mask_recorte_2_1.tiff
# Imagem renomeada: 000036_2021-09-06-00:00_2021-09-06-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000036_2021-09-06-00:00_2021-09-06-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000005_2022-08-23-00:00_2022-08-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_1.tiff -> 000005_2022-08-23-00:00_2022-08-23-23:59_Sentinel-2_L2A_Mask_recorte_1_1.tiff
# Imagem renomeada: 000103_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_5.tiff -> 000103_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_Mask_recorte_1_5.tiff
# Imagem renomeada: 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_4.tiff -> 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_Mask_recorte_3_4.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_15_5.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_15_5.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_14_6.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_14_6.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_0.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_6_0.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_8_3.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_8_3.tiff
# Imagem renomeada: 000059_2023-06-07-00:00_2023-06-07-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000059_2023-06-07-00:00_2023-06-07-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000187_2023-02-07-00:00_2023-02-07-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000187_2023-02-07-00:00_2023-02-07-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_8_10.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_8_10.tiff
# Imagem renomeada: 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_2.tiff -> 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_Mask_recorte_4_2.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_4.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_6_4.tiff
# Imagem renomeada: 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_1.tiff -> 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_1_1.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_11_5.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_11_5.tiff
# Imagem renomeada: 000125_2023-06-21-00:00_2023-06-21-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_3.tiff -> 000125_2023-06-21-00:00_2023-06-21-23:59_Sentinel-2_L2A_Mask_recorte_4_3.tiff
# Imagem renomeada: 000103_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_1.tiff -> 000103_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_Mask_recorte_2_1.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_9_9.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_9_9.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_6.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_4_6.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_9_0.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_9_0.tiff
# Imagem renomeada: 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_0.tiff -> 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_Mask_recorte_3_0.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_5.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_4_5.tiff
# Imagem renomeada: 000057_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_1.tiff -> 000057_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_2_1.tiff
# Imagem renomeada: 000050_2022-08-24-00:00_2022-08-24-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_2.tiff -> 000050_2022-08-24-00:00_2022-08-24-23:59_Sentinel-2_L2A_Mask_recorte_4_2.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_9.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_1_9.tiff
# Imagem renomeada: 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_4.tiff -> 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_Mask_recorte_0_4.tiff
# Imagem renomeada: 000102_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_1.tiff -> 000102_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_Mask_recorte_2_1.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_10_5.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_10_5.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_1.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_7_1.tiff
# Imagem renomeada: 000015_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_1.tiff -> 000015_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_Mask_recorte_1_1.tiff
# Imagem renomeada: 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_2.tiff -> 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_Mask_recorte_2_2.tiff
# Imagem renomeada: 000125_2023-06-21-00:00_2023-06-21-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_2.tiff -> 000125_2023-06-21-00:00_2023-06-21-23:59_Sentinel-2_L2A_Mask_recorte_5_2.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_13_2.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_13_2.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_21_4.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_21_4.tiff
# Imagem renomeada: 000038_2023-06-23-00:00_2023-06-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000038_2023-06-23-00:00_2023-06-23-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000197_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000197_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_12.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_6_12.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_15_6.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_15_6.tiff
# Imagem renomeada: 000083_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_1.tiff -> 000083_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_4_1.tiff
# Imagem renomeada: 000079_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_3.tiff -> 000079_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_Mask_recorte_1_3.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_25_0.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_25_0.tiff
# Imagem renomeada: 000202_2023-06-03-00:00_2023-06-03-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_1.tiff -> 000202_2023-06-03-00:00_2023-06-03-23:59_Sentinel-2_L2A_Mask_recorte_3_1.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_8_0.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_8_0.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_26_4.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_26_4.tiff
# Imagem renomeada: 000129_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_3.tiff -> 000129_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_1_3.tiff
# Imagem renomeada: 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_5.tiff -> 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_0_5.tiff
# Imagem renomeada: 000094_2021-01-05-00:00_2021-01-05-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_0.tiff -> 000094_2021-01-05-00:00_2021-01-05-23:59_Sentinel-2_L2A_Mask_recorte_2_0.tiff
# Imagem renomeada: 000187_2023-02-07-00:00_2023-02-07-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000187_2023-02-07-00:00_2023-02-07-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000179_2021-09-16-00:00_2021-09-16-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_0.tiff -> 000179_2021-09-16-00:00_2021-09-16-23:59_Sentinel-2_L2A_Mask_recorte_4_0.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000111_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000111_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_15_3.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_15_3.tiff
# Imagem renomeada: 000075_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_2.tiff -> 000075_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_Mask_recorte_1_2.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_13_4.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_13_4.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_13_5.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_13_5.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_12_2.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_12_2.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_2.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_2_2.tiff
# Imagem renomeada: 000102_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_2.tiff -> 000102_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_Mask_recorte_0_2.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_3.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_7_3.tiff
# Imagem renomeada: 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_5.tiff -> 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_Mask_recorte_4_5.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_21_5.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_21_5.tiff
# Imagem renomeada: 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_2.tiff -> 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_2_2.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_9.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_6_9.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_11_4.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_11_4.tiff
# Imagem renomeada: 000036_2021-09-06-00:00_2021-09-06-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_0.tiff -> 000036_2021-09-06-00:00_2021-09-06-23:59_Sentinel-2_L2A_Mask_recorte_1_0.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_7.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_6_7.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_12_1.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_12_1.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_9_9.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_9_9.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_10_3.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_10_3.tiff
# Imagem renomeada: 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_5.tiff -> 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_Mask_recorte_6_5.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_6.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_0_6.tiff
# Imagem renomeada: 000170_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_0.tiff -> 000170_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_2_0.tiff
# Imagem renomeada: 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_2.tiff -> 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_Mask_recorte_7_2.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_19_7.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_19_7.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_15_8.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_15_8.tiff
# Imagem renomeada: 000134_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_1.tiff -> 000134_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_2_1.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_9_8.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_9_8.tiff
# Imagem renomeada: 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_4.tiff -> 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_Mask_recorte_5_4.tiff
# Imagem renomeada: 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_11.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_4_11.tiff
# Imagem renomeada: 000179_2021-09-16-00:00_2021-09-16-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_5.tiff -> 000179_2021-09-16-00:00_2021-09-16-23:59_Sentinel-2_L2A_Mask_recorte_2_5.tiff
# Imagem renomeada: 000098_2023-06-21-00:00_2023-06-21-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_2.tiff -> 000098_2023-06-21-00:00_2023-06-21-23:59_Sentinel-2_L2A_Mask_recorte_0_2.tiff
# Imagem renomeada: 000122_2023-06-05-00:00_2023-06-05-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_2.tiff -> 000122_2023-06-05-00:00_2023-06-05-23:59_Sentinel-2_L2A_Mask_recorte_3_2.tiff
# Imagem renomeada: 000083_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_2.tiff -> 000083_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_4_2.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_14_9.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_14_9.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_12.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_0_12.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_15_1.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_15_1.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_8_12.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_8_12.tiff
# Imagem renomeada: 000015_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_0.tiff -> 000015_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_Mask_recorte_3_0.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_14_9.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_14_9.tiff
# Imagem renomeada: 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_2.tiff -> 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_Mask_recorte_2_2.tiff
# Imagem renomeada: 000164_2023-05-03-00:00_2023-05-03-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_2.tiff -> 000164_2023-05-03-00:00_2023-05-03-23:59_Sentinel-2_L2A_Mask_recorte_1_2.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_12_3.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_12_3.tiff
# Imagem renomeada: 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_9_3.tiff -> 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_Mask_recorte_9_3.tiff
# Imagem renomeada: 000098_2023-06-21-00:00_2023-06-21-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000098_2023-06-21-00:00_2023-06-21-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_20_5.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_20_5.tiff
# Imagem renomeada: 000038_2023-06-23-00:00_2023-06-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_1.tiff -> 000038_2023-06-23-00:00_2023-06-23-23:59_Sentinel-2_L2A_Mask_recorte_1_1.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_8_13.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_8_13.tiff
# Imagem renomeada: 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_5.tiff -> 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_Mask_recorte_3_5.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_8_1.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_8_1.tiff
# Imagem renomeada: 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_6.tiff -> 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_Mask_recorte_5_6.tiff
# Imagem renomeada: 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_0.tiff -> 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_2_0.tiff
# Imagem renomeada: 000122_2023-06-05-00:00_2023-06-05-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_3.tiff -> 000122_2023-06-05-00:00_2023-06-05-23:59_Sentinel-2_L2A_Mask_recorte_3_3.tiff
# Imagem renomeada: 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_0.tiff -> 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_5_0.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_31_9.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_31_9.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_28_8.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_28_8.tiff
# Imagem renomeada: 000083_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_2.tiff -> 000083_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_1_2.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_9_5.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_9_5.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_8_0.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_8_0.tiff
# Imagem renomeada: 000131_2023-06-05-00:00_2023-06-05-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_4.tiff -> 000131_2023-06-05-00:00_2023-06-05-23:59_Sentinel-2_L2A_Mask_recorte_1_4.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_2.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_0_2.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_4.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_1_4.tiff
# Imagem renomeada: 000103_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_1.tiff -> 000103_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_Mask_recorte_1_1.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_14_2.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_14_2.tiff
# Imagem renomeada: 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_3.tiff -> 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_Mask_recorte_5_3.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_6.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_3_6.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_15_3.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_15_3.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_8.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_6_8.tiff
# Imagem renomeada: 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_0.tiff -> 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_Mask_recorte_4_0.tiff
# Imagem renomeada: 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_2.tiff -> 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_Mask_recorte_3_2.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_13_7.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_13_7.tiff
# Imagem renomeada: 000076_2023-06-10-00:00_2023-06-10-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000076_2023-06-10-00:00_2023-06-10-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000083_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_1.tiff -> 000083_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_2_1.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_17_0.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_17_0.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_10.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_5_10.tiff
# Imagem renomeada: 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_9_1.tiff -> 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_Mask_recorte_9_1.tiff
# Imagem renomeada: 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_5.tiff -> 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_Mask_recorte_0_5.tiff
# Imagem renomeada: 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_4.tiff -> 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_Mask_recorte_0_4.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_3.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_3_3.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_13_3.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_13_3.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_8_6.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_8_6.tiff
# Imagem renomeada: 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_4.tiff -> 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_Mask_recorte_2_4.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_18_1.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_18_1.tiff
# Imagem renomeada: 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_0.tiff -> 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_Mask_recorte_7_0.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_6.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_0_6.tiff
# Imagem renomeada: 000024_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000024_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_14_4.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_14_4.tiff
# Imagem renomeada: 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_2.tiff -> 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_4_2.tiff
# Imagem renomeada: 000018_2023-06-08-00:00_2023-06-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_0.tiff -> 000018_2023-06-08-00:00_2023-06-08-23:59_Sentinel-2_L2A_Mask_recorte_2_0.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_3.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_7_3.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_12_1.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_12_1.tiff
# Imagem renomeada: 000167_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_1.tiff -> 000167_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_3_1.tiff
# Imagem renomeada: 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_3.tiff -> 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_Mask_recorte_0_3.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_4.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_7_4.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_31_5.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_31_5.tiff
# Imagem renomeada: 000083_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_0.tiff -> 000083_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_3_0.tiff
# Imagem renomeada: 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_0.tiff -> 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_Mask_recorte_4_0.tiff
# Imagem renomeada: 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_6.tiff -> 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_Mask_recorte_1_6.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_0.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_3_0.tiff
# Imagem renomeada: 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_4.tiff -> 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_Mask_recorte_0_4.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_11.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_1_11.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_2.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_1_2.tiff
# Imagem renomeada: 000202_2023-06-03-00:00_2023-06-03-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_2.tiff -> 000202_2023-06-03-00:00_2023-06-03-23:59_Sentinel-2_L2A_Mask_recorte_2_2.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_14_0.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_14_0.tiff
# Imagem renomeada: 000134_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_1.tiff -> 000134_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_1_1.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_16_2.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_16_2.tiff
# Imagem renomeada: 000015_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_0.tiff -> 000015_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_Mask_recorte_1_0.tiff
# Imagem renomeada: 000011_2021-08-05-00:00_2021-08-05-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000011_2021-08-05-00:00_2021-08-05-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_0.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_6_0.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_9_1.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_9_1.tiff
# Imagem renomeada: 000197_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_1.tiff -> 000197_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_1_1.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_18_0.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_18_0.tiff
# Imagem renomeada: 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000007_2022-08-26-00:00_2022-08-26-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_15_4.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_15_4.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_20_1.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_20_1.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_8.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_5_8.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_21_0.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_21_0.tiff
# Imagem renomeada: 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_1.tiff -> 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_Mask_recorte_6_1.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_5.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_7_5.tiff
# Imagem renomeada: 000075_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_3.tiff -> 000075_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_Mask_recorte_2_3.tiff
# Imagem renomeada: 000079_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_6.tiff -> 000079_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_Mask_recorte_2_6.tiff
# Imagem renomeada: 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_27_3.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_27_3.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_5.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_1_5.tiff
# Imagem renomeada: 000125_2023-06-21-00:00_2023-06-21-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_0.tiff -> 000125_2023-06-21-00:00_2023-06-21-23:59_Sentinel-2_L2A_Mask_recorte_5_0.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_18_2.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_18_2.tiff
# Imagem renomeada: 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_4.tiff -> 000153_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_4_4.tiff
# Imagem renomeada: 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_0.tiff -> 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_Mask_recorte_6_0.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_13.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_0_13.tiff
# Imagem renomeada: 000134_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000134_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000111_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_1.tiff -> 000111_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_Mask_recorte_3_1.tiff
# Imagem renomeada: 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_3.tiff -> 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_0_3.tiff
# Imagem renomeada: 000050_2022-08-24-00:00_2022-08-24-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_2.tiff -> 000050_2022-08-24-00:00_2022-08-24-23:59_Sentinel-2_L2A_Mask_recorte_5_2.tiff
# Imagem renomeada: 000094_2021-01-05-00:00_2021-01-05-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_2.tiff -> 000094_2021-01-05-00:00_2021-01-05-23:59_Sentinel-2_L2A_Mask_recorte_2_2.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_11.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_7_11.tiff
# ...
# Imagem renomeada: 000111_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_3.tiff -> 000111_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_Mask_recorte_1_3.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_3.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_6_3.tiff
# Imagem renomeada: 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_2.tiff -> 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_Mask_recorte_5_2.tiff
# Imagem renomeada: 000111_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_3.tiff -> 000111_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_Mask_recorte_3_3.tiff
# Imagem renomeada: 000089_2023-05-08-00:00_2023-05-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000089_2023-05-08-00:00_2023-05-08-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000005_2022-08-23-00:00_2022-08-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_3.tiff -> 000005_2022-08-23-00:00_2022-08-23-23:59_Sentinel-2_L2A_Mask_recorte_3_3.tiff
# Imagem renomeada: 000161_2023-05-08-00:00_2023-05-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_2.tiff -> 000161_2023-05-08-00:00_2023-05-08-23:59_Sentinel-2_L2A_Mask_recorte_0_2.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_16_12.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_16_12.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_10.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_7_10.tiff
# Imagem renomeada: 000093_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_2.tiff -> 000093_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_3_2.tiff
# Imagem renomeada: 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_7.tiff -> 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_Mask_recorte_1_7.tiff
# Imagem renomeada: 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_4.tiff -> 000194_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_1_4.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_5.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_5_5.tiff
# Imagem renomeada: 000125_2023-06-21-00:00_2023-06-21-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000125_2023-06-21-00:00_2023-06-21-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_5.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_2_5.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_14_6.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_14_6.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_17_8.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_17_8.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_12_12.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_12_12.tiff
# Imagem renomeada: 000131_2023-06-05-00:00_2023-06-05-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_4.tiff -> 000131_2023-06-05-00:00_2023-06-05-23:59_Sentinel-2_L2A_Mask_recorte_2_4.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_25_1.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_25_1.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_20_9.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_20_9.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_0.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_1_0.tiff
# Imagem renomeada: 000102_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_2.tiff -> 000102_2023-05-13-00:00_2023-05-13-23:59_Sentinel-2_L2A_Mask_recorte_3_2.tiff
# Imagem renomeada: 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_2.tiff -> 000019_2022-07-27-00:00_2022-07-27-23:59_Sentinel-2_L2A_Mask_recorte_3_2.tiff
# Imagem renomeada: 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_0.tiff -> 000159_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_Mask_recorte_6_0.tiff
# Imagem renomeada: 000103_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_1.tiff -> 000103_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_Mask_recorte_0_1.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_5.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_2_5.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_31_8.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_31_8.tiff
# Imagem renomeada: 000103_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_1.tiff -> 000103_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_Mask_recorte_3_1.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_19_3.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_19_3.tiff
# Imagem renomeada: 000094_2021-01-05-00:00_2021-01-05-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_0.tiff -> 000094_2021-01-05-00:00_2021-01-05-23:59_Sentinel-2_L2A_Mask_recorte_6_0.tiff
# Imagem renomeada: 000103_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_3.tiff -> 000103_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_Mask_recorte_2_3.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_23_2.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_23_2.tiff
# Imagem renomeada: 000079_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_2.tiff -> 000079_2023-06-02-00:00_2023-06-02-23:59_Sentinel-2_L2A_Mask_recorte_1_2.tiff
# Imagem renomeada: 000038_2023-06-23-00:00_2023-06-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_1.tiff -> 000038_2023-06-23-00:00_2023-06-23-23:59_Sentinel-2_L2A_Mask_recorte_2_1.tiff
# Imagem renomeada: 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_2.tiff -> 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_Mask_recorte_3_2.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_0.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_5_0.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_11_4.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_11_4.tiff
# Imagem renomeada: 000075_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000075_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_2.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_5_2.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_11_4.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_11_4.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_16_3.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_16_3.tiff
# Imagem renomeada: 000202_2023-06-03-00:00_2023-06-03-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_2.tiff -> 000202_2023-06-03-00:00_2023-06-03-23:59_Sentinel-2_L2A_Mask_recorte_0_2.tiff
# Imagem renomeada: 000141_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_0.tiff -> 000141_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_Mask_recorte_2_0.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_8.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_4_8.tiff
# Imagem renomeada: 000050_2022-08-24-00:00_2022-08-24-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_1.tiff -> 000050_2022-08-24-00:00_2022-08-24-23:59_Sentinel-2_L2A_Mask_recorte_7_1.tiff
# Imagem renomeada: 000050_2022-08-24-00:00_2022-08-24-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_8_1.tiff -> 000050_2022-08-24-00:00_2022-08-24-23:59_Sentinel-2_L2A_Mask_recorte_8_1.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_18_9.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_18_9.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_11_9.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_11_9.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_8.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_7_8.tiff
# Imagem renomeada: 000075_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_0.tiff -> 000075_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_Mask_recorte_3_0.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_8.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_4_8.tiff
# Imagem renomeada: 000131_2023-06-05-00:00_2023-06-05-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_4_2.tiff -> 000131_2023-06-05-00:00_2023-06-05-23:59_Sentinel-2_L2A_Mask_recorte_4_2.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_21_0.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_21_0.tiff
# Imagem renomeada: 000141_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_4.tiff -> 000141_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_Mask_recorte_0_4.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_6_5.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_6_5.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_1.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_1_1.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_8_9.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_8_9.tiff
# Imagem renomeada: 000093_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_0.tiff -> 000093_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_2_0.tiff
# Imagem renomeada: 000111_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_2.tiff -> 000111_2023-06-12-00:00_2023-06-12-23:59_Sentinel-2_L2A_Mask_recorte_3_2.tiff
# Imagem renomeada: 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_6.tiff -> 000107_2023-05-28-00:00_2023-05-28-23:59_Sentinel-2_L2A_Mask_recorte_2_6.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_13_6.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_13_6.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_9_8.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_9_8.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_11.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_7_11.tiff
# Imagem renomeada: 000050_2022-08-24-00:00_2022-08-24-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_7_0.tiff -> 000050_2022-08-24-00:00_2022-08-24-23:59_Sentinel-2_L2A_Mask_recorte_7_0.tiff
# Imagem renomeada: 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000144_2023-05-14-00:00_2023-05-14-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_16_5.tiff -> 000113_2021-09-08-00:00_2021-09-08-23:59_Sentinel-2_L2A_Mask_recorte_16_5.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_31_0.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_31_0.tiff
# Imagem renomeada: 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_12_9.tiff -> 000173_2021-08-08-00:00_2021-08-08-23:59_Sentinel-2_L2A_Mask_recorte_12_9.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_16_9.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_16_9.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_20_3.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_20_3.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_16_8.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_16_8.tiff
# Imagem renomeada: 000141_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_4.tiff -> 000141_2023-05-23-00:00_2023-05-23-23:59_Sentinel-2_L2A_Mask_recorte_1_4.tiff
# Imagem renomeada: 000047_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_2.tiff -> 000047_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_1_2.tiff
# Imagem renomeada: 000094_2021-01-05-00:00_2021-01-05-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_1_2.tiff -> 000094_2021-01-05-00:00_2021-01-05-23:59_Sentinel-2_L2A_Mask_recorte_1_2.tiff
# Imagem renomeada: 000134_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_0.tiff -> 000134_2023-06-17-00:00_2023-06-17-23:59_Sentinel-2_L2A_Mask_recorte_2_0.tiff
# Imagem renomeada: 000179_2021-09-16-00:00_2021-09-16-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_2.tiff -> 000179_2021-09-16-00:00_2021-09-16-23:59_Sentinel-2_L2A_Mask_recorte_3_2.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_23_1.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_23_1.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_18_5.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_18_5.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_21_6.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_21_6.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_0_0.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_0_0.tiff
# Imagem renomeada: 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_14_2.tiff -> 000175_2022-01-30-00:00_2022-01-30-23:59_Sentinel-2_L2A_Mask_recorte_14_2.tiff
# Imagem renomeada: 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_5_5.tiff -> 000033_2021-09-14-00:00_2021-09-14-23:59_Sentinel-2_L2A_Mask_recorte_5_5.tiff
# Imagem renomeada: 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_3_5.tiff -> 000205_2021-09-13-00:00_2021-09-13-23:59_Sentinel-2_L2A_Mask_recorte_3_5.tiff
# Imagem renomeada: 000057_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_B12_(Raw)Mask_recorte_2_0.tiff -> 000057_2023-06-15-00:00_2023-06-15-23:59_Sentinel-2_L2A_Mask_recorte_2_0.tiff

# %% [markdown]
# Fit

# %%
# Função para redimensionar as imagens de entrada para o tamanho desejado
def redimensionar_imagem(imagem, altura_desejada, largura_desejada):
    return resize(imagem, (altura_desejada, largura_desejada), mode='constant', preserve_range=True)

# Obter número de imagens de treino
NUM_TRAIN_IMAGES = len([f for f in os.listdir(diretorio_imagens) if "Mask" in f])

# Obter listas de nomes de arquivo Sentinel-2
banda11_list = sorted([f for f in os.listdir(diretorio_imagens) if "B11_(Raw)" in f])
banda12_list = sorted([f for f in os.listdir(diretorio_imagens) if "B12_(Raw)" in f])
seg_list = sorted([f for f in os.listdir(diretorio_imagens) if "Mask" in f])
# color_list = sorted([f for f in os.listdir(diretorio_imagens) if "Wildfires" in f])

with pd.option_context("display.max_columns", None):
    df = pd.DataFrame({'banda11': banda11_list, 'banda12': banda12_list, 'seg': seg_list})
    # df = pd.DataFrame({'banda11': banda11_list, 'banda12': banda12_list, 'seg': seg_list, 'color': color_list})

# Obter listas de IDs
train_banda11_id_list = df['banda11'].tolist()
train_banda12_id_list = df['banda12'].tolist()
train_mask_id_list = df['seg'].tolist()
# train_color_id_list = df['color'].tolist()

# criando as matrizes para armazenar as imagens 
X_train = np.zeros((NUM_TRAIN_IMAGES, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.float32)
Y_train = np.zeros((NUM_TRAIN_IMAGES, IMG_HEIGHT, IMG_WIDTH, IMG_MASK_CHANNELS), dtype=bool)
# Z_train = np.zeros((NUM_TRAIN_IMAGES, IMG_HEIGHT, IMG_WIDTH, IMG_COLOR_CHANNELS), dtype=np.float32)

# X_test = np.zeros((NUM_TRAIN_IMAGES, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.float32)
# Y_test = np.zeros((NUM_TRAIN_IMAGES, IMG_HEIGHT, IMG_WIDTH, IMG_MASK_CHANNELS), dtype=bool)
# Z_test = np.zeros((NUM_TRAIN_IMAGES, IMG_HEIGHT, IMG_WIDTH, IMG_COLOR_CHANNELS), dtype=np.float32)

# Iterar sobre as listas usando enumerate
for i, (banda11_id, banda12_id, mask_id) in enumerate(zip(train_banda11_id_list, train_banda12_id_list, train_mask_id_list)):
#for i, (banda11_id, banda12_id, mask_id, color_id) in enumerate(zip(train_banda11_id_list, train_banda12_id_list, train_mask_id_list, train_color_id_list)):
    # Construir caminhos completos
    path_banda11 = os.path.join(diretorio_imagens, banda11_id)
    path_banda12 = os.path.join(diretorio_imagens, banda12_id)
    path_seg = os.path.join(diretorio_imagens, mask_id)
    # path_color = os.path.join(diretorio_imagens, color_id)

    try:
        # Ler as imagens
        with rs.open(path_banda11) as img11, rs.open(path_banda12) as img12, rs.open(path_seg) as img_seg:
        # with rs.open(path_banda11) as img11, rs.open(path_banda12) as img12, rs.open(path_seg) as img_seg, rs.open(path_color) as img_color:
            banda11 = img11.read(1)
            banda12 = img12.read(1)
            seg = img_seg.read(1)
            # color = img_color.read(1)

        # Juntar as bandas
        bandas = np.dstack((banda11, banda12))

        # Redimensionar as bandas para o tamanho desejado
        bandas_redimensionadas = redimensionar_imagem(bandas, IMG_HEIGHT, IMG_WIDTH)

        # Transformar bandas em valores entre 0 e 255
        bandas_redimensionadas = (bandas_redimensionadas / np.max(bandas_redimensionadas)) * 255

        # Inserir a imagem em X_train/X_test
        X_train[i] = bandas_redimensionadas
        # X_test[i] = bandas_redimensionadas

        # Redimensionar a máscara para a forma (IMG_HEIGHT, IMG_WIDTH, 1)
        mask = resize(seg, (IMG_HEIGHT, IMG_WIDTH, 1), mode='constant', preserve_range=True)

        # Normalizar valores da máscara para True/False (ou 0/1)
        mask = mask.astype(bool)

        # Inserir a máscara em Y_train/Y_test
        Y_train[i] = mask
        # Y_test[i] = mask

        # Inserir a imagem em Z_train/Z_test
        # Z_train[i] = resize(color, (IMG_HEIGHT, IMG_WIDTH, IMG_COLOR_CHANNELS), mode='constant', preserve_range=True)
        # Z_test[i] = resize(color, (IMG_HEIGHT, IMG_WIDTH, IMG_COLOR_CHANNELS), mode='constant', preserve_range=True)

    except (rs.errors.RasterioIOError, FileNotFoundError) as e:
        print(f"Erro ao abrir a imagem {banda11_id}: {e}")

print('Shape do X_train:', X_train.shape)
print('Shape do Y_train:', Y_train.shape)
# print('Shape do Z_train:', Z_train.shape)

# print('Shape do X_test:', X_test.shape)
# print('Shape do Y_test:', Y_test.shape)
# # print('Shape do Z_test:', Z_test.shape)
# Out:
# Shape do X_train: (2122, 64, 64, 2)
# Shape do Y_train: (2122, 64, 64, 1)

# %% [markdown]
# salva treino

# %%
# Salvar X_train
X_train_file = os.path.join(diretorio_imagens, 'X_train.npy')
np.save(X_train_file, X_train)

# Salvar Y_train
Y_train_file = os.path.join(diretorio_imagens, 'Y_train.npy')
np.save(Y_train_file, Y_train)

# # Salvar Y_train
# Z_train_file = os.path.join(diretorio_imagens, 'Z_train.npy')
# np.save(Z_train_file, Z_train)

# %% [markdown]
# Visualização de uma imagem a partir dos arquivos salvos.

# %%
# Selecionar a primeira amostra da array X_test, que contém a imagem composta pelas duas bandas
bandas = X_train[6]
color = Z_train[6]
mask = Y_train[6]

# # Separar as bandas individuais (assumindo que as bandas estão na última dimensão)
banda11 = bandas[:, :, 0]
banda12 = bandas[:, :, 1]
mask = mask[:, :, 0]

# # Plotar as bandas individualmente
plt.subplot(1, 4, 1)
plt.imshow(banda11, cmap='gray')
plt.title('Banda 11')

plt.subplot(1, 4, 2)
plt.imshow(banda12, cmap='gray')
plt.title('Banda 12')

plt.subplot(1, 4, 3)
plt.imshow(mask, cmap='gray')
plt.title('mask')

plt.subplot(1, 4, 4)
color_normalized = color / 255.0
plt.imshow(color_normalized)
plt.title('Color')


plt.show()

# %% [markdown]
# Salva as entradas da Rede

# %%
# # Salvar X_test
# X_test_file = os.path.join(diretorio_imagens, 'X_test.npy')
# np.save(X_test_file, X_test)

# # Salvar Y_train
# Y_test_file = os.path.join(diretorio_imagens, 'Y_test.npy')
# np.save(Y_test_file, Y_test)

# # Salvar Z_train
# Z_test_file = os.path.join(diretorio_imagens, 'Z_test.npy')
# np.save(Z_test_file, Z_test)

# %% [markdown]
# Visualização de uma imagem a partir dos arquivos salvos.

# %%
# # Selecionar a primeira amostra da array X_test, que contém a imagem composta pelas duas bandas
# bandas = X_test[15]
# mask = Y_test[15]
# color = Z_test[15]

# # Separar as bandas individuais (assumindo que as bandas estão na última dimensão)
# banda11 = bandas[:, :, 0]
# banda12 = bandas[:, :, 1]

# # Plotar as bandas individualmente
# plt.subplot(1, 4, 1)
# plt.imshow(banda11, cmap='gray')
# plt.title('Banda 11')

# plt.subplot(1, 4, 2)
# plt.imshow(banda12, cmap='gray')
# plt.title('Banda 12')

# plt.subplot(1, 4, 3)
# plt.imshow(mask, cmap='gray')
# plt.title('mask')

# plt.subplot(1, 4, 4)
# color_normalized = color / 255.0
# plt.imshow(color_normalized)
# plt.title('Color')

# plt.show()

# %%
from PIL import Image
import os
import matplotlib.pyplot as plt

lista_imagens = []

# Listar todos os arquivos no diretório
arquivos = os.listdir(diretorio_imagens)

# Iterar sobre os arquivos e carregar as imagens .tiff no array
for arquivo in arquivos:
    if "Wildfires" in arquivo:
        caminho_arquivo = os.path.join(diretorio_imagens, arquivo)
        imagem = Image.open(caminho_arquivo)
        lista_imagens.append(imagem)

# Plotar a primeira imagem da lista
if lista_imagens:
    plt.imshow(lista_imagens[15])
    plt.axis('off')  # Opcional, para ocultar os eixos
    plt.show()
else:
    print("Nenhuma imagem .tiff contendo 'Wildfires' encontrada no diretório.")
